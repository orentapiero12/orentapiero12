# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import plotly.graph_objects as go
import json
import requests
import datetime
import iso8601

from datetime import datetime
from tqdm import tqdm

sns.set()
plt.rcParams["figure.figsize"] = (18,10)

# %%
def ohlc_plot(df,start = '2018',end = '2021',Log = False):
    if Log:
        fig = go.Figure(data=[go.Candlestick(x=df.loc[start:end].index,
                        open=np.log(df.Open.loc[start:end]),
                        high=np.log(df.High.loc[start:end]),
                        low=np.log(df.Low.loc[start:end]),
                        close=np.log(df.Close.loc[start:end]))])
    else:
        fig = go.Figure(data=[go.Candlestick(x=df.loc[start:end].index,
                        open=(df.Open.loc[start:end]),
                        high=(df.High.loc[start:end]),
                        low=(df.Low.loc[start:end]),
                        close=(df.Close.loc[start:end]))])


    fig.update_layout(xaxis_rangeslider_visible=False)
    fig.show()
    return

# %%
eth = yf.Ticker('GBPUSD=X')#("ETH-USD")
data = eth.history(period="max")[['Open','High','Low','Close','Volume']]
data = data.reset_index()

# %%
from fbprophet import Prophet

df = pd.concat([data['Date'],np.log(data['Close'])],axis = 1)
df = df.rename(columns = {"Date":"ds","Close":"y"}) 
m = Prophet(daily_seasonality = True) # the Prophet class (model)
m.fit(df.loc[:'2015']) # fit the model using all data
# Out:
# Initial log joint probability = -22.534
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       4884.58     0.0136752       818.295           1           1      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       5105.45     0.0320344        1156.4           1           1      237
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299        5276.6    0.00460686       569.229           1           1      354
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       5369.58     0.0189729       1205.78           1           1      460
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      499       5494.18    0.00396611       1001.72      0.9189      0.9189      573
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      599       5545.84   0.000713481       369.942           1           1      687
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      699       5574.69   0.000780614       255.372           1           1      801
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      799       5584.16   0.000664349       172.479           1           1      926
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      899       5591.78   0.000268995       165.525      0.2671      0.2671     1048
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      999       5599.63    0.00410124       783.398           1           1     1157
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1099       5602.56    0.00895981       362.589           1           1     1276
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1199       5607.64    0.00655723       92.5968           1           1     1389
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1205       5607.65    1.0459e-05       94.7775    1.33e-07       0.001     1465  LS failed, Hessian reset
#     1299       5610.22    0.00165499       173.887      0.2511      0.8792     1587
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1399        5619.9   0.000605599        137.82           1           1     1702
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1499        5626.4    0.00168459       313.715           1           1     1813
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1513       5627.23   3.97437e-05       378.267   1.023e-07       0.001     1874  LS failed, Hessian reset
#     1599       5630.09    0.00368113       254.595           1           1     1968
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1699       5631.45    4.1001e-05       224.273      0.4245      0.4245     2087
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1799       5631.93   2.72747e-05       143.912      0.4963      0.4963     2218
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1891       5632.73   7.12669e-06       71.5316   8.041e-08       0.001     2364  LS failed, Hessian reset
#     1899        5632.8   0.000797203       211.719           1           1     2375
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     1999       5633.42    0.00191669       128.964           1           1     2501
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2005       5633.44   1.83462e-05       176.792   8.799e-08       0.001     2565  LS failed, Hessian reset
#     2024       5633.57   2.03371e-05       117.058   4.257e-07       0.001     2634  LS failed, Hessian reset
#     2060       5633.68   2.57338e-05       212.046   1.709e-07       0.001     2722  LS failed, Hessian reset
#     2099       5633.74   2.13618e-05       88.3402      0.6886      0.6886     2767
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2199       5635.18   0.000143383       66.4951           1           1     2886
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2209       5635.23   6.46627e-06        49.765   5.676e-08       0.001     2946  LS failed, Hessian reset
#     2248       5635.34   7.01687e-06       71.2094   1.174e-07       0.001     3039  LS failed, Hessian reset
#     2299       5635.39   0.000242244       127.077           1           1     3102
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2399       5636.43    0.00323192       204.334           1           1     3217
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2499       5638.42   0.000286378        69.719      0.2575           1     3355
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2599       5638.59    0.00043739       152.016           1           1     3486
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2699       5639.08     0.0163257       240.422      0.9335      0.9335     3604
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2737       5639.25    7.3822e-06         63.75   6.064e-08       0.001     3695  LS failed, Hessian reset
#     2799       5639.49   0.000641189       123.929      0.3442           1     3775
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#     2833       5639.55   7.85522e-06        51.818   1.366e-07       0.001     3866  LS failed, Hessian reset
#     2860       5639.55   2.33963e-07       54.9262      0.2051     0.02051     3911
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
future = m.make_future_dataframe(periods=365) #we need to specify the number of days in future
prediction = m.predict(future)
m.plot(prediction)
plt.plot(df.loc['2015':,'ds'],df.loc['2015':,'y'],'r.')
plt.title("Prediction of the Google Stock Price using the Prophet")
plt.xlabel("Date")
plt.ylabel("Close Stock Price")
plt.show()
